# %% [markdown]
# <a href="https://colab.research.google.com/github/ElizabethB111/MESA-8410-Final-Project/blob/main/Q1_Q2_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Adressing Question 1: Are WHD more effective when women or men are running them, with effectiveness indicated by actions (FIR, DIR, NCR, Dial-100, arrests)?
#
# Addressing Question 2: How much does a WHD in a police station promote the reporting of GBV compared to a police station with no WHD?
#
# Reading In and then cleaning Admin_Wide_Data
#
# (User survey_endline_data: thought of including this but won't because of possible social pressures on users to give positive answers).
#
# Goal is to clean compare rates of FIR, DIR, NCR, Dial-100, and arrests between women-run WHD and regular WHD.
#
# This same cleaned data frame will suffice for answering Question 2 comparing the influence of a WHD in a police station with no WHD in reporting GBV.

# %%
# IMPORT LIBRARIES BELOW
import pandas as pd
import seaborn as sns

# Add a special library for working with tables:
from tabulate import tabulate

# %% [markdown]
# ### Reading in the data
# First mount the google drive;
# The data is in csv format and stored in "". Import the data into a dataframe.

# %%
# the code below allows you to access your Google Drive.
from google.colab import drive

drive.mount('/content/drive')

# root_dir is the path to your My_Drive folder.
root_dir = "/content/drive/My Drive/"

# Store the dataframes in the following directory.
data_folder = root_dir + "Colab Notebooks/Final Project/Data/"

# the CSV data files are in the following locations
inputfile1 = "/content/drive/My Drive/Colab Notebooks/MPP Science Replication Package/Data/Admin/csv/admin_wide data.dta.csv"


# Read the CSV file into a dataframe
admin_wide_data = pd.read_csv(inputfile1)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Do some simple overviews of the data
# The next few cells will ask you to use different `pandas` functions to learn about the dataset.

# %%
# Use `head()` to get an overview of the first few records in the dataset
print ('Admin Wide Sample Records')
admin_wide_data.head(5)
# Out:
# Admin Wide Sample Records
#    Unnamed: 0  ps_code  urban  dist_urban  strat_pca  treatment  dist_id  \
# 0           0   1001.0  Rural         1.0  -0.234041  Treatment   1000.0
# 1           1   1002.0  Rural         1.0  -0.960574    Control   1000.0
# 2           2   1003.0  Rural         1.0   1.042663    Control   1000.0
# 3           3   1004.0  Rural         1.0  -1.590761  Treatment   1000.0
# 4           4   1005.0  Rural         1.0  -1.570695  Treatment   1000.0
#
#    regular_whd  women_whd  e_caw_rate  ...  e_fir_overall_count  \
# 0          0.0        1.0    0.000000  ...                   30
# 1          0.0        0.0    0.114887  ...                   11
# 2          0.0        0.0    0.043200  ...                   68
# 3          1.0        0.0    0.000000  ...                   12
# 4          0.0        1.0    0.000000  ...                   12
#
#    e_fir_caw_count  e_fir_bywomen_count  e_arrest_count  e_dir_count  \
# ...

# %%
# Check the number of rows and columns with `shape`
print("Rows and Column Count, Admin Wide Data:",admin_wide_data.shape)
# Out:
# Rows and Column Count, Admin Wide Data: (1980, 28)

# %%
# Drop Months 1-4 From Admin Wide because program officially launched in May 2019;

#admin_wide_data = admin_wide_data.drop(['month'== 1, 2, 3, 4 ], axis='rows')
admin_wide_data = admin_wide_data.query('month not in [1, 2, 3, 4]')

# %%
# Check - Use `head()` to get an overview of the first few records in the dataset
print ('Admin Wide Sample Records')
admin_wide_data.head(5)
# Out:
# Admin Wide Sample Records
#      Unnamed: 0  ps_code  urban  dist_urban  strat_pca  treatment  dist_id  \
# 540         540   1001.0  Rural         1.0  -0.234041  Treatment   1000.0
# 541         541   1002.0  Rural         1.0  -0.960574    Control   1000.0
# 542         542   1003.0  Rural         1.0   1.042663    Control   1000.0
# 543         543   1004.0  Rural         1.0  -1.590761  Treatment   1000.0
# 544         544   1005.0  Rural         1.0  -1.570695  Treatment   1000.0
#
#      regular_whd  women_whd  e_caw_rate  ...  e_fir_overall_count  \
# 540          0.0        1.0    0.000000  ...                   43
# 541          0.0        0.0    0.114887  ...                   28
# 542          0.0        0.0    0.043200  ...                   51
# 543          1.0        0.0    0.000000  ...                    8
# 544          0.0        1.0    0.000000  ...                   10
#
#      e_fir_caw_count  e_fir_bywomen_count  e_arrest_count  e_dir_count  \
# ...

# %%
admin_wide_data.shape
# Out:
# (1440, 28)

# %%
# Check Data Types of Columns in Resulting Dataset;

admin_wide_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1440 entries, 540 to 1979
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1440 non-null   int64
#  1   ps_code                 1440 non-null   float64
#  2   urban                   1440 non-null   object
#  3   dist_urban              1440 non-null   float64
#  4   strat_pca               1440 non-null   float64
#  5   treatment               1440 non-null   object
#  6   dist_id                 1440 non-null   float64
#  7   regular_whd             1440 non-null   float64
#  8   women_whd               1440 non-null   float64
#  9   e_caw_rate              1440 non-null   float64
#  10  month                   1440 non-null   float64
#  11  b_fir_overall_count     1440 non-null   int64
#  12  b_fir_caw_count         1440 non-null   int64
#  13  b_fir_bywomen_count     1440 non-null   int64
# ...

# %%
admin_wide_data.head()
# Out:
#      Unnamed: 0  ps_code  urban  dist_urban  strat_pca  treatment  dist_id  \
# 540         540   1001.0  Rural         1.0  -0.234041  Treatment   1000.0
# 541         541   1002.0  Rural         1.0  -0.960574    Control   1000.0
# 542         542   1003.0  Rural         1.0   1.042663    Control   1000.0
# 543         543   1004.0  Rural         1.0  -1.590761  Treatment   1000.0
# 544         544   1005.0  Rural         1.0  -1.570695  Treatment   1000.0
#
#      regular_whd  women_whd  e_caw_rate  ...  e_fir_overall_count  \
# 540          0.0        1.0    0.000000  ...                   43
# 541          0.0        0.0    0.114887  ...                   28
# 542          0.0        0.0    0.043200  ...                   51
# 543          1.0        0.0    0.000000  ...                    8
# 544          0.0        1.0    0.000000  ...                   10
#
#      e_fir_caw_count  e_fir_bywomen_count  e_arrest_count  e_dir_count  \
# ...

# %%
# For numeric columns (the default selection), round to 2 decimal places for better readability.
numeric_summary_stats = admin_wide_data.describe().round(2)
# Print the numeric summaries:
print("Numeric Summary Statistics: (vertical)")
display(numeric_summary_stats)

# For categorical columns, include 'object' (strings), 'category', and 'bool' (true/false) types.
print("\nCategorical Summary Statistics: (vertical)")
categorical_summary_stats = admin_wide_data.describe(include = ['object', 'category', 'bool'])
# Print the categorical summaries:
display(categorical_summary_stats)

# Transpose the summary statistics tables (turn them sideways) to make them more readable, using .T
numeric_summary_stats_transposed = numeric_summary_stats.T
categorical_summary_stats_transposed = categorical_summary_stats.T

# Display the transposed summary statistics
print("\nNumeric Summary Statistics: (transposed)")
display(numeric_summary_stats_transposed)

print("\nCategorical Summary Statistics: (transposed)")
display(categorical_summary_stats_transposed)
# Out:
# Numeric Summary Statistics: (vertical)
#        Unnamed: 0   ps_code  dist_urban  strat_pca   dist_id  regular_whd  \
# count     1440.00   1440.00      1440.0    1440.00   1440.00      1440.00
# mean      1259.50   5857.17         8.6       0.00   5766.67         0.34
# std        415.84   3110.52         4.9       1.38   3059.93         0.47
# min        540.00   1001.00         1.0      -2.36   1000.00         0.00
# 25%        899.75   3045.75         4.0      -1.11   3000.00         0.00
# 50%       1259.50   5090.50         8.0      -0.13   5000.00         0.00
# 75%       1619.25   8135.25        12.0       0.99   8000.00         1.00
# max       1979.00  12180.00        18.0       3.99  12000.00         1.00
#
#        women_whd  e_caw_rate    month  b_fir_overall_count  ...  \
# count    1440.00     1440.00  1440.00              1440.00  ...
# mean        0.33        0.09     8.50                31.69  ...
# std         0.47        0.14     2.29                19.61  ...
# ...

# %%
# Output to CSV;

# Save the data to "admin_data.csv"

admin_wide_data.to_csv("/content/drive/My Drive/Colab Notebooks/Final Project/Data/admin_wide_monthdrop_data.csv", index=False)

# %%
station_level_means = admin_wide_data.groupby('ps_code')[['e_caw_rate', 'e_fir_overall_count', 'e_fir_caw_count', 'e_fir_bywomen_count', 'e_arrest_count', 'e_dir_count']].mean().reset_index()

# Display the result
print(station_level_means)
# Out:
#      ps_code  e_caw_rate  e_fir_overall_count  e_fir_caw_count  \
# 0     1001.0    0.000000               33.500           10.375
# 1     1002.0    0.114887               17.000            2.000
# 2     1003.0    0.043200               42.625            8.250
# 3     1004.0    0.000000               13.000            2.625
# 4     1005.0    0.000000               11.000            1.250
# ..       ...         ...                  ...              ...
# 175  12176.0    0.060906               14.500            3.375
# 176  12177.0    0.000000               19.750            4.625
# 177  12178.0    0.000000               11.125            1.375
# 178  12179.0    0.000000               34.875           11.000
# 179  12180.0    0.024804               18.875            3.375
#
#      e_fir_bywomen_count  e_arrest_count  e_dir_count
# 0                  5.000          14.000        0.500
# 1                  1.625           3.125        0.000
# ...

# %%
station_level_means.to_csv("/content/drive/My Drive/Colab Notebooks/Final Project/Data/admin_wide_station_level_means_data.csv", index=False)

# %%
station_level_means = admin_wide_data.groupby(['ps_code', 'treatment'])[['women_whd', 'regular_whd', 'e_caw_rate', 'e_fir_overall_count', 'e_fir_caw_count', 'e_fir_bywomen_count', 'e_arrest_count', 'e_dir_count']].mean().reset_index()

# Display the result
print(station_level_means)
# Out:
#      ps_code  treatment  women_whd  regular_whd  e_caw_rate  \
# 0     1001.0  Treatment        1.0          0.0    0.000000
# 1     1002.0    Control        0.0          0.0    0.114887
# 2     1003.0    Control        0.0          0.0    0.043200
# 3     1004.0  Treatment        0.0          1.0    0.000000
# 4     1005.0  Treatment        1.0          0.0    0.000000
# ..       ...        ...        ...          ...         ...
# 175  12176.0    Control        0.0          0.0    0.060906
# 176  12177.0  Treatment        0.0          1.0    0.000000
# 177  12178.0    Control        0.0          0.0    0.000000
# 178  12179.0  Treatment        1.0          0.0    0.000000
# 179  12180.0  Treatment        0.0          1.0    0.024804
#
#      e_fir_overall_count  e_fir_caw_count  e_fir_bywomen_count  \
# 0                 33.500           10.375                5.000
# 1                 17.000            2.000                1.625
# ...

# %%
station_level_means.to_csv("/content/drive/My Drive/Colab Notebooks/Final Project/Data/admin_wide_station_level_means_data.csv", index=False)

# %%
station_level_means = admin_wide_data.groupby(['ps_code', 'treatment']) [['women_whd', 'b_fir_overall_count', 'b_fir_caw_count', \
                                                          'b_fir_bywomen_count', 'regular_whd', 'e_caw_rate', 'e_fir_overall_count', \
                                                          'e_fir_caw_count', 'e_fir_bywomen_count', 'b_arrest_count', 'e_arrest_count', \
                                                          'e_dir_count', 'b_dir_count']].mean().reset_index()

# Display the result
print(station_level_means)
# Out:
#      ps_code  treatment  women_whd  b_fir_overall_count  b_fir_caw_count  \
# 0     1001.0  Treatment        1.0               31.625           11.000
# 1     1002.0    Control        0.0               19.250            2.250
# 2     1003.0    Control        0.0               45.125            2.000
# 3     1004.0  Treatment        0.0               11.875            4.500
# 4     1005.0  Treatment        1.0               13.875            2.750
# ..       ...        ...        ...                  ...              ...
# 175  12176.0    Control        0.0               18.250            4.250
# 176  12177.0  Treatment        0.0               14.625            2.625
# 177  12178.0    Control        0.0                9.875            2.500
# 178  12179.0  Treatment        1.0               36.125           10.500
# 179  12180.0  Treatment        0.0               24.500            1.875
#
#      b_fir_bywomen_count  regular_whd  e_caw_rate  e_fir_overall_count  \
# ...

# %%
station_level_means.to_csv("/content/drive/My Drive/Colab Notebooks/Final Project/Data/admin_wide_beg_end_station_level_means_data.csv", index=False)
